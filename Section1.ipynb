# %%
import pandas as pd 

df = pd.read_csv('BPD_Part_1_Victim_Based_Crime_Data.csv', nrows=1000000)
#df = pd.read_csv('Parking_Citations.csv', nrows=1000000) 
df.head(100)
# Out:
#      CrimeDate CrimeTime CrimeCode               Location  \
# 0   07/20/2019  00:12:00        4A        1800 ORLEANS ST
# 1   07/20/2019  02:00:00       3AF      700 N LINWOOD AVE
# 2   07/20/2019  23:33:00        5A        3100 BARCLAY ST
# 3   07/20/2019  15:50:00        6G         1000 W 36TH ST
# 4   07/20/2019  19:00:00        6E        800 GILRUBIN CT
# 5   07/20/2019  05:14:00        4D      1000 W LANVALE ST
# 6   07/20/2019  21:04:00      3AJF       1000 SOMERSET ST
# 7   07/20/2019  09:00:00      3AJF        3900 JUNIPER RD
# 8   07/20/2019  15:45:00        4E         2800 CARVER RD
# 9   07/20/2019  02:20:00        4C      1400 E PRESTON ST
# 10  07/20/2019  05:30:00        7A    100 S MONASTERY AVE
# 11  07/20/2019  19:00:00        6E   6800 REISTERSTOWN RD
# 12  07/20/2019  15:21:00        6G        5600 LOTHIAN RD
# 13  07/20/2019  12:50:00        4E        800 GILRUBIN CT
# 14  07/20/2019  02:38:00        4E      300 WHITRIDGE AVE
# ...

# %%
import datetime

df.rename(columns={'ImportDate': 'Import_Date'}, inplace=True)



#df.head(3)

#day = df[' Import_Date'].str.split('/').apply(lambda x: int(x[0]))
#Month = df[' Import_Date'].str.split('/').apply(lambda x: int(x[1]))
#Year = df[' Import_Date'].str.split('/').apply(lambda x: int(x[2]))
# Out:
#    Citation      Tag ExpMM  ExpYY State  Make                         Address  \
# 0  82691651  69943CF    04   19.0    MD  MAZD  1300 BLK EAST NORTHERN PKWY WB
# 1  85937226  T720887    12   18.0    MD  ACUR        300 BLK NORTH BEND RD SB
# 2  82691115  5BA2678    03   19.0    MD  TOYT          5000 BLK ROLAND AVE NB
#
#    ViolCode         Description  ViolFine  ... Balance  PenaltyDate  OpenFine  \
# 0        32  Fixed Speed Camera      40.0  ...     0.0          NaN       0.0
# 1        32  Fixed Speed Camera      40.0  ...    40.0          NaN       0.0
# 2        32  Fixed Speed Camera      40.0  ...     0.0          NaN       0.0
#
#    OpenPenalty  NoticeDate             Import_Date Neighborhood  \
# 0          0.0         NaN  04/26/2018 04:02:00 AM          NaN
# 1          0.0         NaN  01/03/2019 04:33:00 AM          NaN
# 2          0.0         NaN  04/26/2018 04:02:00 AM          NaN
#
#   PoliceDistrict CouncilDistrict  \
# 0            NaN             NaN
# ...

# %%
import matplotlib.pyplot as plt#is you don't want to make a regular call on #plt.show use this line
# %matplotlib inline
x1 = df.loc[df['username']== 'SodaStream', 'likes']
#x1 = df.loc[df['favorite_color'] != 'yellow']
x2 = df.loc[df['username']=='ANSYSInc', 'likes']
x3 = df.loc[df['username']=='MyAquaAmerica', 'likes']
x4 = df.loc[df['username']=='Qualcomm', 'likes']
x5 = df.loc[df['username']=='eaglepharmaceuticals', 'likes']
kwargs = dict(alpha=0.9, bins=10)
plt.hist(x1, **kwargs, color='g', label='SodaStream')
plt.hist(x2, **kwargs, color='b', label='ANSYSInc')
#plt.hist(x3, **kwargs, color='r', label='MyAquaAmerica')
#plt.hist(x4, **kwargs, color='y', label='Qualcomm')
#plt.hist(x5, **kwargs, color='m', label='eaglepharmaceuticals')
#plt.gca().set(title='Company # of likes', ylabel='Frequency')
#plt.xlim(50,200)
plt.legend();
